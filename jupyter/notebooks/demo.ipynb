# %% [markdown]
# # Demo of a Python Jupyter Notebook with Pandas

# %% [markdown]
# Download an example dataset from Pandas

# %%
from pathlib import Path
import pandas as pd

# %%
filepath: Path = Path(r"../data/titanic.csv")

# %% [markdown]
# ## Show DataFrame

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Show Plots of data

# %%
ax = titanic['Fare'].hist()
title = ax.set_title('Fare Price Distribution')
y_label = ax.set_ylabel('Frequency')
x_label = ax.set_xlabel('Fare Price (USD)')
